# %%
to design a program train validation and test set , test set 33% , standard scaler , hidden layer 1 6 neurons , relu , hidden layer 2  6 neurons , relu , output layer 1 unit sigmoid loss binary cross entropy
